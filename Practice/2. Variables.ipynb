# %%
FirstName='Anusuya'
SecondName='Ponnusamy'
print('FirstName+SecondName')
print(FirstName+SecondName)
# Out:
# FirstName+SecondName
# AnusuyaPonnusamy

# %%
#Pro-secret - Program once you have the output in mind
print("The addition of two number")
num1=10
print("The number1:", num1)
num2=20
print("The number2:",num2)
add=num1+num2
print("The Answer:",add)
# Out:
# The addition of two number
# The number1: 10
# The number2: 20
# The Answer: 30

# %%
#Input function 
#1. To get user input
#2. The input is always got a string from user. Hence for mathematical calculation, need to type
#cast to int
num1=input("Enter the num1:")
num2=input("Enter the num2:")
add=num1+num2
print(add)
# Out:
# Enter the num1: 10
# Enter the num2: 20
# 1020

# %%
#Input function 
#3. Typecasting to Int to input function
num1=int(input("Enter the num1:"))
num2=int(input("Enter the num2:"))
add=num1+num2
print(add)
# Out:
# Enter the num1: 10
# Enter the num2: 20
# 30

# %%
#Asterik(*) while execution
num=int(input("Enter your name"))
# Out:
# Enter your name 12
