# %%
print()

# %%
print("Welcome to Hope AI")
# Out:
# Welcome to Hope AI

# %%
print("123wel!@E$")
# Out:
# 123wel!@E$

# %%
#Namespace error
#Print("hi") 
#-- Give Namespace error since the keyword print is starting with Caps "P". 
#-- This comes up with Namespace error since not defined.

# %%
num1=10
num2=30
add=num1+num2
print("add")
print(add)
# Out:
# add
# 40
